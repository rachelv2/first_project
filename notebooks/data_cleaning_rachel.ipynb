# %%
import pandas as pd
import polars as pl

wdi_pl = pl.read_csv("../data/raw/WB_WDI.csv")
display(wdi_pl)

wdi_df = pd.read_csv("../data/raw/WB_WDI.csv")
display(wdi_df)
# Out:
# shape: (9_032_658, 43)
# ┌─────────────┬────────────┬────────┬──────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ STRUCTURE   ┆ STRUCTURE_ ┆ ACTION ┆ FREQ ┆ … ┆ TIME_FORMA ┆ UNIT_MULT_ ┆ OBS_STATUS ┆ OBS_CONF_L │
# │ ---         ┆ ID         ┆ ---    ┆ ---  ┆   ┆ T_LABEL    ┆ LABEL      ┆ _LABEL     ┆ ABEL       │
# │ str         ┆ ---        ┆ str    ┆ str  ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │             ┆ str        ┆        ┆      ┆   ┆ str        ┆ str        ┆ str        ┆ str        │
# ╞═════════════╪════════════╪════════╪══════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ datastructu ┆ WB.DATA360 ┆ I      ┆ A    ┆ … ┆ Annual     ┆ Units      ┆ Normal     ┆ Public     │
# │ re          ┆ :DS_DATA36 ┆        ┆      ┆   ┆            ┆            ┆ value      ┆            │
# │             ┆ 0(1.3)     ┆        ┆      ┆   ┆            ┆            ┆            ┆            │
# ...
